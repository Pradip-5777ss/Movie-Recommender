# %% [markdown]
# ## Extracting 2020 movies from Wikipedia

# %%
import pandas as pd
import numpy as np
from tmdbv3api import TMDb
import json
import requests
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 269  DECEMBER         25       We Can Be Heroes
# 270  DECEMBER         25      News of the World
# 271  DECEMBER         25  One Night in Miami...
# 272  DECEMBER         25  Promising Young Woman
# 273  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ...

# %%
tmdb = TMDb()
tmdb.api_key='e2f23b720ffb3e476ae26f11f7ab66fd'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 269  DECEMBER         25       We Can Be Heroes
# 270  DECEMBER         25      News of the World
# 271  DECEMBER         25  One Night in Miami...
# 272  DECEMBER         25  Promising Young Woman
# 273  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ...

# %%
df_2020_movies = df[['Title', 'Cast and crew', 'genres']]

# %%
df_2020_movies
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020_movies['director_name'] = df_2020_movies['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\3920122266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_movies['director_name'] = df_2020_movies['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor_1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020_movies['actor_1_name'] =df_2020_movies['Cast and crew'].map(lambda x: get_actor_1(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\1739264240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_movies['actor_1_name'] =df_2020_movies['Cast and crew'].map(lambda x: get_actor_1(str(x)))

# %%
def get_actor_2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020_movies['actor_2_name'] = df_2020_movies['Cast and crew'].map(lambda x: get_actor_2(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\564821508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_movies['actor_2_name'] = df_2020_movies['Cast and crew'].map(lambda x: get_actor_2(str(x)))

# %%
def get_actor_3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020_movies['actor_3_name'] = df_2020_movies['Cast and crew'].map(lambda x: get_actor_3(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\3497776232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_movies['actor_3_name'] = df_2020_movies['Cast and crew'].map(lambda x: get_actor_3(str(x)))

# %%
df_2020_movies
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020_movies = df_2020_movies.rename(columns={'Title':'movie_title'})

# %%
new_2020_movie_list = df_2020_movies.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_2020_movie_list
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %%
new_2020_movie_list['actor_2_name'] = new_2020_movie_list['actor_2_name'].replace(np.nan, 'unknown')
new_2020_movie_list['actor_3_name'] = new_2020_movie_list['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_2020_movie_list['movie_title'] = new_2020_movie_list['movie_title'].str.lower()

# %%
new_2020_movie_list['combine'] = new_2020_movie_list['actor_1_name']+' '+new_2020_movie_list['actor_2_name']+' ' + \
    new_2020_movie_list['actor_3_name']+' ' + \
    new_2020_movie_list['director_name']+' '+new_2020_movie_list['genres']

# %%
new_2020_movie_list
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# ...

# %% [markdown]
# ## Extracting 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                   Title  \
# 0     JANUARY        1.0     Shadow in the Cloud
# 1     JANUARY       13.0         The White Tiger
# 2     JANUARY       14.0             Locked Down
# 3     JANUARY       15.0                 The Dig
# 4     JANUARY       15.0        Outside the Wire
# ..        ...        ...                     ...
# 353  DECEMBER       25.0  The Tragedy of Macbeth
# 354  DECEMBER       25.0    A Journal for Jordan
# 355  DECEMBER       25.0       American Underdog
# 356  DECEMBER       26.0                 Memoria
# 357  DECEMBER        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                              Netflix
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# 4                                              Netflix
# ...

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021_movies = df[['Title','Cast and crew','genres']]

# %%
df_2021_movies
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021_movies['director_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\465748157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_movies['director_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor_1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021_movies['actor_1_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_actor_1(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\263207904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_movies['actor_1_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_actor_1(str(x)))

# %%
def get_actor_2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021_movies['actor_2_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_actor_2(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\1703673716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_movies['actor_2_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_actor_2(str(x)))

# %%
def get_actor_3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021_movies['actor_3_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_actor_3(str(x)))
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\972348692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_movies['actor_3_name'] = df_2021_movies['Cast and crew'].map(lambda x: get_actor_3(str(x)))

# %%
df_2021_movies
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# ...

# %%
df_2021_movies = df_2021_movies.rename(columns={'Title':'movie_title'})

# %%
new_2021_movie_list = df_2021_movies.loc[:, [
    'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'genres', 'movie_title']]

# %%
new_2021_movie_list['actor_2_name'] = new_2021_movie_list['actor_2_name'].replace(np.nan, 'unknown')
new_2021_movie_list['actor_3_name'] = new_2021_movie_list['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_2021_movie_list['movie_title'] = new_2021_movie_list['movie_title'].str.lower()

# %%
new_2021_movie_list['combine'] = new_2021_movie_list['actor_1_name'] + ' ' + new_2021_movie_list['actor_2_name'] + ' '+ new_2021_movie_list['actor_3_name'] + ' '+ new_2021_movie_list['director_name'] +' ' + new_2021_movie_list['genres']

# %%
new_2021_movie_list
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
combine_df = new_2020_movie_list.append(new_2021_movie_list, ignore_index=True)
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\4053330386.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combine_df = new_2020_movie_list.append(new_2021_movie_list, ignore_index=True)

# %%
combine_df
# Out:
#                                          director_name  \
# 0                                        Nicolas Pesce
# 1                                       William Eubank
# 2                                        Miguel Arteta
# 3                                            Jon Avnet
# 4                                       Anthony Jerjen
# ..                                                 ...
# 627                                          Joel Coen
# 628                                  Denzel Washington
# 629                                     Erwin brothers
# 630  Apichatpong Weerasethakul (director/acreenplay...
# 631                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Andrea Riseborough      Demián Bichir
# 1                                      Kristen Stewart     Vincent Cassel
# 2                                      Tiffany Haddish         Rose Byrne
# ...

# %%
old_processing_data = pd.read_csv('../Data/ProcessedData/wikipedia2018_19MoviesPreprocessData.csv')

# %%
old_processing_data
# Out:
#       Unnamed: 0           director_name       actor_1_name  \
# 0              0           James Cameron        CCH Pounder
# 1              1          Gore Verbinski        Johnny Depp
# 2              2              Sam Mendes    Christoph Waltz
# 3              3       Christopher Nolan          Tom Hardy
# 4              4             Doug Walker        Doug Walker
# ...          ...                     ...                ...
# 5873        5873  Nick Bruno, Troy Quane         Will Smith
# 5874        5874            Greta Gerwig      Saoirse Ronan
# 5875        5875              Sam Mendes      George MacKay
# 5876        5876   Destin Daniel Cretton  Michael B. Jordan
# 5877        5877         Chinonye Chukwu      Alfre Woodard
#
#               actor_2_name          actor_3_name  \
# 0         Joel David Moore             Wes Studi
# 1            Orlando Bloom        Jack Davenport
# 2             Rory Kinnear      Stephanie Sigman
# ...

# %%
new_final_df = old_processing_data.append(combine_df, ignore_index=True)
# Out:
# C:\Users\pradi\AppData\Local\Temp\ipykernel_18968\3019476396.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_final_df = old_processing_data.append(combine_df, ignore_index=True)

# %%
new_final_df
# Out:
#       Unnamed: 0                                      director_name  \
# 0            0.0                                      James Cameron
# 1            1.0                                     Gore Verbinski
# 2            2.0                                         Sam Mendes
# 3            3.0                                  Christopher Nolan
# 4            4.0                                        Doug Walker
# ...          ...                                                ...
# 6505         NaN                                          Joel Coen
# 6506         NaN                                  Denzel Washington
# 6507         NaN                                     Erwin brothers
# 6508         NaN  Apichatpong Weerasethakul (director/acreenplay...
# 6509         NaN                                                nan
#
#                                            actor_1_name       actor_2_name  \
# ...

# %%
new_final_df.isna().sum()
# Out:
# Unnamed: 0       632
# director_name      0
# actor_1_name       0
# actor_2_name       0
# actor_3_name       0
# genres             5
# movie_title        1
# combine            5
# dtype: int64

# %%
new_final_df = new_final_df.drop('Unnamed: 0', axis=1)

# %%
new_final_df = new_final_df.dropna(how='any')

# %%
new_final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# combine          0
# dtype: int64

# %%
new_final_df.to_csv('../Data/ProcessedData/wikipedia2020_21MoviesProcessing.csv')

# %%
new_final_df.shape
# Out:
# (6504, 7)
